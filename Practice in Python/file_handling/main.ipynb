# %%
file=open("shopping_list.txt",'r')
content=file.read()
file.close()
print(content)
# Out:
# khathal
# am
# ab
# jam

# %%
print(repr(content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(repr(content))
#
# NameError: name 'content' is not defined

# %%
print(content.split())
# Out:
# ['khathal', 'am', 'ab', 'jam']

# %%
sentence='\nfaysal\nsami\novi'
print(sentence.split())
# Out:
# ['faysal', 'sami', 'ovi']

# %%
items=sentence.split()
items.sort()
for item in items:
    print('Name: ',item)
# Out:
# Name:  faysal
# Name:  ovi
# Name:  sami

# %%
file=open('fx.txt','a')
content=file.write('\ncrap')
file.close()
